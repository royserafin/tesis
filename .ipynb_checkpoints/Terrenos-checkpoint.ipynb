# %%
import pandas as pd
import math
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point, Polygon, LineString
import descartes
import numpy as np

# %%
estados = 'Shapes\México_Estados\México_Estados.shp'
mex = gpd.read_file(estados)
mex.head()
# Out:
#   CODIGO               ESTADO  \
# 0   MX02      Baja California
# 1   MX03  Baja California Sur
# 2   MX18              Nayarit
# 3   MX14              Jalisco
# 4   MX01       Aguascalientes
#
#                                             geometry
# 0  MULTIPOLYGON (((-113.13972 29.01778, -113.2405...
# 1  MULTIPOLYGON (((-111.20612 25.80278, -111.2302...
# 2  MULTIPOLYGON (((-106.62108 21.56531, -106.6475...
# 3  POLYGON ((-101.52490 21.85664, -101.58830 21.7...
# 4  POLYGON ((-101.84620 22.01176, -101.96530 21.8...

# %%
# %matplotlib inline
mex.plot()

# %%
cobertura = pd.read_excel('PROMTEL Estudio de Cobertura (2).xlsx', index_col=0, sheet_name='Análisis de población')

# %%
def distancia(a,b):
    return math.sqrt((a[0]-b[0])**2 + (a[1] - b[1])**2)

# %%
fig,ax=plt.subplots(figsize = (15,15))
mex.plot(ax=ax)

# %%
df = pd.read_csv('terrenos.csv',header=0,encoding = 'unicode_escape')
crs = {'init' : 'epsg:4326'}
df.head()
# Out:
#                                                Title  \
# 0  LagunasInterior . Punta TiburÃ³n Residencial; ...
# 1              La Escondida Residencial â Terrenos
# 2                       El Molino Residencial & Golf
# 3                            Club Cenote Residencial
# 4  Punta TiburÃ³n Residencial; Marina & Golf - Bo...
#
#                                              Address  \
# 0  Km. 4.5 Carretera Federal Boca del RÃ­o - AntÃ...
# 1  Octava Avenida y Veracruz||RincÃ³n de La Sierr...
# 2  Paseos El Molino # 302; LeÃ³n; Gto||Balcones d...
# 3  Ruta de los Cenotes Km 19 DesviaciÃ³n Delirios...
# 4  Km. 4.5 Carretera Federal Boca del RÃ­o - AntÃ...
#
#                                          Descripcion       Precio  TamaÃ±o  \
# 0  Punta tiburÃ³n residencial se encuentra en la ...    $ 769;500  180 mÂ²
# 1  La Escondida ResidencialResidencias y Lotes de...    $ 711;000  140 mÂ²
# 2  El Molino; Residencial & GolfEs un impresionan...    $ 845;719  250 mÂ²
# 3  Club Cenote ResidencialAmplios Terrenos en el ...  $ 1;039;000  800 mÂ²
# 4  Punta tiburÃ³n residencial se encuentra en la ...    $ 723;672  180 mÂ²
#
#      Latitud    Longitud
# 0  19.067293  -96.080747
# 1  25.641346 -100.198342
# 2  21.185639 -101.699237
# 3  20.847873  -87.220608
# 4  19.067293  -96.080747

# %%
geometry = [Point(xy) for xy in zip(df['Longitud'], df['Latitud'])]
geometry[:3]
# Out:
# [<shapely.geometry.point.Point at 0x260ecdb9b70>,
#  <shapely.geometry.point.Point at 0x260ecdb9ba8>,
#  <shapely.geometry.point.Point at 0x260ecdb9cc0>]

# %%
geo_df = gpd.GeoDataFrame(df,
                         crs = crs,
                         geometry = geometry)
geo_df.head()
# Out:
#                                                Title  \
# 0  LagunasInterior . Punta TiburÃ³n Residencial; ...
# 1              La Escondida Residencial â Terrenos
# 2                       El Molino Residencial & Golf
# 3                            Club Cenote Residencial
# 4  Punta TiburÃ³n Residencial; Marina & Golf - Bo...
#
#                                              Address  \
# 0  Km. 4.5 Carretera Federal Boca del RÃ­o - AntÃ...
# 1  Octava Avenida y Veracruz||RincÃ³n de La Sierr...
# 2  Paseos El Molino # 302; LeÃ³n; Gto||Balcones d...
# 3  Ruta de los Cenotes Km 19 DesviaciÃ³n Delirios...
# 4  Km. 4.5 Carretera Federal Boca del RÃ­o - AntÃ...
#
#                                          Descripcion       Precio  TamaÃ±o  \
# 0  Punta tiburÃ³n residencial se encuentra en la ...    $ 769;500  180 mÂ²
# 1  La Escondida ResidencialResidencias y Lotes de...    $ 711;000  140 mÂ²
# 2  El Molino; Residencial & GolfEs un impresionan...    $ 845;719  250 mÂ²
# 3  Club Cenote ResidencialAmplios Terrenos en el ...  $ 1;039;000  800 mÂ²
# 4  Punta tiburÃ³n residencial se encuentra en la ...    $ 723;672  180 mÂ²
#
#      Latitud    Longitud                     geometry
# 0  19.067293  -96.080747   POINT (-96.08075 19.06729)
# 1  25.641346 -100.198342  POINT (-100.19834 25.64135)
# 2  21.185639 -101.699237  POINT (-101.69924 21.18564)
# 3  20.847873  -87.220608   POINT (-87.22061 20.84787)
# 4  19.067293  -96.080747   POINT (-96.08075 19.06729)

# %%
def cuadricula(xmin,ymin,xmax,ymax, m, n):
    x_step = (xmax-xmin)/m
    y_step = (ymax-ymin)/n
    
    cols = np.linspace(xmin, xmax, m+1)
    rows = np.linspace(ymin, ymax, n+1)

    #cols = list(range(int(np.floor(xmin)), int(np.ceil(xmax)), x_step))
    #rows = list(range(int(np.floor(ymin)), int(np.ceil(ymax)), y_step))
    #rows.reverse()
    rows = np.flip(rows)
    cols = cols[:-1]
    rows = rows[:-1]

    polygons = []
    for x in cols:
        for y in rows:
            polygons.append( Polygon([(x,y), (x+x_step, y), (x+x_step, y-y_step), (x, y-y_step)]) )

    grid = gpd.GeoDataFrame({'geometry':polygons})
    return grid

# %%
fig, ax = plt.subplots(figsize=(15,15))
mex.plot(ax=ax)
xmin,ymin,xmax,ymax = mex.total_bounds
#cuadricula(xmin,ymin,xmax,ymax, 10,10)['geometry'][0:5].plot(ax=ax, alpha=0.5, linewidth=0.5)
cuad = cuadricula(xmin,ymin,xmax,ymax, 10,10)
for poly in cuad['geometry']:
    x,y = poly.exterior.xy
    cantidad=0
    for point in geo_df['geometry']:
        if poly.contains(point):
            cantidad += 1
    print(cantidad)
    plt.plot(x,y, color='black')
geo_df[(geo_df['Latitud']>=ymin) & (geo_df['Latitud']<=ymax) 
    & (geo_df['Longitud']>=xmin) & (geo_df['Longitud']<=xmax)].plot(ax = ax, markersize = 20, color = 'red', marker = 'o', label='terrenos')
plt.legend(prop={'size': 15})

# %%
# Out:
# c:\programdata\miniconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
