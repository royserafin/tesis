# %% [markdown]
# # Librerías necesarias

# %%
import pandas as pd
import math
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib import cm
from shapely.geometry import Point, Polygon, LineString, MultiPolygon
from shapely.ops import nearest_points
import descartes
import numpy as np
from pyproj import Proj, transform
import scipy
from scipy.spatial import cKDTree
from mpl_toolkits.axes_grid1 import make_axes_locatable
import scipy
import seaborn as sn
import pysal as ps
from sklearn import cluster
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
import libpysal as lp
from dbfread import DBF
# %matplotlib inline

# %% [markdown]
# # Importación de archivos

# %%
#Asignación de localidad a terreno
cobertura = gpd.read_file('conjunto_de_datos/Cobertura/cobertura.shp')
terrenos = gpd.read_file('conjunto_de_datos/Terrenos/terrenos.shp')
terrenos.head()
# Out:
#                                                Title  \
# 0  LagunasInterior . Punta TiburÃ³n Residencial; ...
# 1              La Escondida Residencial â Terrenos
# 2                       El Molino Residencial & Golf
# 3                            Club Cenote Residencial
# 4  Punta TiburÃ³n Residencial; Marina & Golf - Bo...
#
#                                              Address  \
# 0  Km. 4.5 Carretera Federal Boca del RÃ­o - AntÃ...
# 1  Octava Avenida y Veracruz||RincÃ³n de La Sierr...
# 2  Paseos El Molino # 302; LeÃ³n; Gto||Balcones d...
# 3  Ruta de los Cenotes Km 19 DesviaciÃ³n Delirios...
# 4  Km. 4.5 Carretera Federal Boca del RÃ­o - AntÃ...
#
#                                           Descripcio     Precio  TamaÃ±o  \
# 0  Punta tiburÃ³n residencial se encuentra en la ...   769500.0  180 mÂ²
# 1  La Escondida ResidencialResidencias y Lotes de...   711000.0  140 mÂ²
# 2  El Molino; Residencial & GolfEs un impresionan...   845719.0  250 mÂ²
# 3  Club Cenote ResidencialAmplios Terrenos en el ...  1039000.0  800 mÂ²
# 4  Punta tiburÃ³n residencial se encuentra en la ...   723672.0  180 mÂ²
#
#      Latitud    Longitud  Tamano   Precio/Tam                     geometry
# 0  19.067293  -96.080747   180.0  4275.000000   POINT (-96.08075 19.06729)
# 1  25.641346 -100.198342   140.0  5078.571429  POINT (-100.19834 25.64135)
# 2  21.185639 -101.699237   250.0  3382.876000  POINT (-101.69924 21.18564)
# 3  20.847873  -87.220608   800.0  1298.750000   POINT (-87.22061 20.84787)
# 4  19.067293  -96.080747   180.0  4020.400000   POINT (-96.08075 19.06729)

# %%
cobertura.head()
# Out:
#          ID  ID ENTIDAD         ENTIDAD  ID MUNICIP       MUNICIPIO  \
# 0  10010001           1  Aguascalientes           1  Aguascalientes
# 1  10010094           1  Aguascalientes           1  Aguascalientes
# 2  10010096           1  Aguascalientes           1  Aguascalientes
# 3  10010100           1  Aguascalientes           1  Aguascalientes
# 4  10010102           1  Aguascalientes           1  Aguascalientes
#
#    ID LOCALID               LOCALIDAD  longitud  latitud  altitud  Población  \
# 0           1          Aguascalientes   1021746   215251     1885     722250
# 1          94          Granja Adelita   1022225   215219     1903         14
# 2          96               Agua Azul   1022127   215303     1863         37
# 3         100           Rancho Alegre   1022222   215116     1880         10
# 4         102  Los Arbolitos [Rancho]   1022126   214649     1860          7
#
#         Clasificac        Rango  HAB_CUB_OP  HAB_SCOB_O  % COB OPER  \
# 0  Localidad Mayor  a) > 10 mil      722250           0         1.0
# 1  Localidad Menor       g)<500          14           0         1.0
# 2  Localidad Menor       g)<500          37           0         1.0
# 3  Localidad Menor       g)<500          10           0         1.0
# 4  Localidad Menor       g)<500           7           0         1.0
#
#   COB OPERAD      Clave                     geometry
# 0         SI  010010001  POINT (-102.29611 21.88083)
# 1         SI  010010094  POINT (-102.37361 21.87194)
# 2         SI  010010096  POINT (-102.35750 21.88417)
# 3         SI  010010100  POINT (-102.37278 21.85444)
# 4         SI  010010102  POINT (-102.35722 21.78028)

# %% [markdown]
# # Asignación de localidad a cada terreno

# %%
def ckdnearest(gdA, gdB):
    nA = np.array(list(zip(gdA.geometry.x, gdA.geometry.y)) )
    nB = np.array(list(zip(gdB.geometry.x, gdB.geometry.y)) )
    btree = cKDTree(nB)
    dist, idx = btree.query(nA, k=1)
    gdf = pd.concat(
        [gdA.reset_index(drop=True), gdB.loc[idx, gdB.columns == 'Clave'].reset_index(drop=True),
         pd.Series(dist, name='dist')], axis=1)
    return gdf

terrenos_loc = ckdnearest(terrenos, cobertura)

# %%
terrenos_loc.head()
# Out:
#                                                Title  \
# 0  LagunasInterior . Punta TiburÃ³n Residencial; ...
# 1              La Escondida Residencial â Terrenos
# 2                       El Molino Residencial & Golf
# 3                            Club Cenote Residencial
# 4  Punta TiburÃ³n Residencial; Marina & Golf - Bo...
#
#                                              Address  \
# 0  Km. 4.5 Carretera Federal Boca del RÃ­o - AntÃ...
# 1  Octava Avenida y Veracruz||RincÃ³n de La Sierr...
# 2  Paseos El Molino # 302; LeÃ³n; Gto||Balcones d...
# 3  Ruta de los Cenotes Km 19 DesviaciÃ³n Delirios...
# 4  Km. 4.5 Carretera Federal Boca del RÃ­o - AntÃ...
#
#                                           Descripcio     Precio  TamaÃ±o  \
# 0  Punta tiburÃ³n residencial se encuentra en la ...   769500.0  180 mÂ²
# 1  La Escondida ResidencialResidencias y Lotes de...   711000.0  140 mÂ²
# 2  El Molino; Residencial & GolfEs un impresionan...   845719.0  250 mÂ²
# 3  Club Cenote ResidencialAmplios Terrenos en el ...  1039000.0  800 mÂ²
# 4  Punta tiburÃ³n residencial se encuentra en la ...   723672.0  180 mÂ²
#
#      Latitud    Longitud  Tamano   Precio/Tam                     geometry  \
# 0  19.067293  -96.080747   180.0  4275.000000   POINT (-96.08075 19.06729)
# 1  25.641346 -100.198342   140.0  5078.571429  POINT (-100.19834 25.64135)
# 2  21.185639 -101.699237   250.0  3382.876000  POINT (-101.69924 21.18564)
# 3  20.847873  -87.220608   800.0  1298.750000   POINT (-87.22061 20.84787)
# 4  19.067293  -96.080747   180.0  4020.400000   POINT (-96.08075 19.06729)
#
#        Clave      dist
# 0  300110292  0.002173
# 1  190310045  0.015914
# 2  110201198  0.001994
# 3  230070078  0.000190
# 4  300110292  0.002173

# %% [markdown]
# # Cálculo de precio promedio de m$^2$ para cada localidad con terrenos publicados

# %%
locs_ter =terrenos_loc.groupby('Clave').mean().reset_index()
locs_ter.head()
# Out:
#        Clave       Precio    Latitud    Longitud    Tamano   Precio/Tam  \
# 0  010010001    6213848.8  21.886016 -102.294572     881.6  6099.877565
# 1  010010106   39250000.0  21.798480 -102.276770   34000.0   821.551724
# 2  010010120  223672100.0  21.715990 -102.306005  446122.0   527.472577
# 3  010010126    1800000.0  22.014230 -102.192930   10000.0   180.000000
# 4  010010135   13993800.0  21.699490 -102.311850    5961.5  6341.248721
#
#        dist
# 0  0.008725
# 1  0.003309
# 2  0.013063
# 3  0.008240
# 4  0.001018

# %%
cobertura = pd.merge(cobertura,locs_ter[['Precio/Tam','Clave']],how='left', on='Clave')

# %%
cobertura.head()
# Out:
#          ID  ID ENTIDAD         ENTIDAD  ID MUNICIP       MUNICIPIO  \
# 0  10010001           1  Aguascalientes           1  Aguascalientes
# 1  10010094           1  Aguascalientes           1  Aguascalientes
# 2  10010096           1  Aguascalientes           1  Aguascalientes
# 3  10010100           1  Aguascalientes           1  Aguascalientes
# 4  10010102           1  Aguascalientes           1  Aguascalientes
#
#    ID LOCALID               LOCALIDAD  longitud  latitud  altitud  Población  \
# 0           1          Aguascalientes   1021746   215251     1885     722250
# 1          94          Granja Adelita   1022225   215219     1903         14
# 2          96               Agua Azul   1022127   215303     1863         37
# 3         100           Rancho Alegre   1022222   215116     1880         10
# 4         102  Los Arbolitos [Rancho]   1022126   214649     1860          7
#
#         Clasificac        Rango  HAB_CUB_OP  HAB_SCOB_O  % COB OPER  \
# 0  Localidad Mayor  a) > 10 mil      722250           0         1.0
# 1  Localidad Menor       g)<500          14           0         1.0
# 2  Localidad Menor       g)<500          37           0         1.0
# 3  Localidad Menor       g)<500          10           0         1.0
# 4  Localidad Menor       g)<500           7           0         1.0
#
#   COB OPERAD      Clave                     geometry   Precio/Tam
# 0         SI  010010001  POINT (-102.29611 21.88083)  6099.877565
# 1         SI  010010094  POINT (-102.37361 21.87194)          NaN
# 2         SI  010010096  POINT (-102.35750 21.88417)          NaN
# 3         SI  010010100  POINT (-102.37278 21.85444)          NaN
# 4         SI  010010102  POINT (-102.35722 21.78028)          NaN

# %%
cob_precio = cobertura[(~cobertura['Precio/Tam'].isna())]
cob_precio['% COB OPER'] = cob_precio['% COB OPER'].astype(int)
# Out:
# c:\programdata\miniconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
cob_precio = cob_precio[['Clave', 'Población', '% COB OPER', 'geometry', 'Precio/Tam']]
cob_precio.head()
# Out:
#         Clave  Población  % COB OPER                     geometry   Precio/Tam
# 0   010010001     722250           1  POINT (-102.29611 21.88083)  6099.877565
# 6   010010106       1382           1  POINT (-102.27444 21.80083)   821.551724
# 9   010010120        935           1  POINT (-102.29556 21.71750)   527.472577
# 12  010010126        509           1  POINT (-102.19806 22.00778)   180.000000
# 15  010010135        234           1  POINT (-102.31083 21.69944)  6341.248721

# %% [markdown]
# # Precios por localidad

# %%
estados = 'conjunto_de_datos/Estados/estados.shp'
mex = gpd.read_file(estados)
#mex

# %%
fig, ax = plt.subplots(figsize=(15,15))
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
mex.plot(ax=ax)
cob_precio.plot(ax=ax,markersize=10,column='Precio/Tam', legend=True,cax=cax, cmap='plasma')
cob_precio[cob_precio['COB OPERAD']=='NO'].plot(ax=ax, markersize=20, color='#58F011',marker='*',legend=True)
red_patch = mpatches.Patch(color='#58F011', label='Localidades sin cobertura')
plt.legend(handles=[red_patch],bbox_to_anchor=(.35, .35),bbox_transform=plt.gcf().transFigure)
#plt.scatter(cob_precio.geometry.x,cob_precio.geometry.y,c=cob_precio['COB OPERAD']=='SI', cmap = cm.RdYlGn)
plt.show()

# %% [markdown]
# # Adjuntar variables ITER (2010)

# %%
def zeros(val,tipo):
    add = ''
    if tipo=='ENT':
        if val//10==0:
            add='0'
    if tipo == 'MUN':
        if val//100==0:
            if val//10==0:
                add='00'
            else:
                add='0'
    if tipo == 'LOC':
        if val//1000==0:
            if val//100==0:
                if val//10==0:
                    add = '000'
                else:
                    add = '00'
            else:
                add = '0'
    return add + str(val)

# %%
def nanfill(row,col,nB):
    if math.isnan(row[col]):
        nA = np.array([row['geometry'].x, row['geometry'].y])
        btree = cKDTree(nB)
        dist, idx = btree.query(nA, k=11)
        nearest = cob_precio.iloc[idx[1:]]
        disp = nearest[nearest[col].notnull()]
        prom = disp[col].head(3).mean()
        return prom
    else:
        return row[col]

# %%
cob_precio = cob_precio.set_index('Clave')
dbf = DBF('conjunto_de_datos/SCINCE/cpv2010_loc_rur_caracteristicas_economicas.dbf', encoding='unicode_escape')
frame = pd.DataFrame(iter(dbf))
dbf = DBF('conjunto_de_datos/SCINCE/cpv2010_loc_urb_caracteristicas_economicas.dbf', encoding='unicode_escape')
frame2 = pd.DataFrame(iter(dbf))
frame3 = pd.concat([frame[['CVEGEO', 'ECO1', 'ECO4']], frame2[['CVEGEO', 'ECO1', 'ECO4']]], ignore_index=True)
cob_precio = pd.merge(cob_precio.reset_index(),frame3,how='left', left_on='Clave', right_on='CVEGEO').drop('CVEGEO',axis=1)
cob_precio = cob_precio.set_index('Clave')
dbf = DBF('conjunto_de_datos/SCINCE/cpv2010_loc_rur_servicios_de_salud.dbf', encoding='unicode_escape')
frame = pd.DataFrame(iter(dbf))
dbf = DBF('conjunto_de_datos/SCINCE/cpv2010_loc_urb_servicios_de_salud.dbf', encoding='unicode_escape')
frame2 = pd.DataFrame(iter(dbf))
frame3 = pd.concat([frame[['CVEGEO', 'SALUD1']], frame2[['CVEGEO', 'SALUD1']]], ignore_index=True)
cob_precio = pd.merge(cob_precio.reset_index(),frame3,how='left', left_on='Clave', right_on='CVEGEO').drop('CVEGEO',axis=1)
cob_precio = cob_precio.set_index('Clave')
dbf = DBF('conjunto_de_datos/SCINCE/cpv2010_loc_rur_viviendas.dbf', encoding='unicode_escape')
frame = pd.DataFrame(iter(dbf))
dbf = DBF('conjunto_de_datos/SCINCE/cpv2010_loc_urb_viviendas.dbf', encoding='unicode_escape')
frame2 = pd.DataFrame(iter(dbf))
frame3 = pd.concat([frame[['CVEGEO', 'VIV2', 'VIV27', 'VIV28', 'VIV31',
                          'VIV32','VIV33', 'VIV34', 'VIV35', 'VIV36']], 
                    frame2[['CVEGEO','VIV2', 'VIV27', 'VIV28',
                          'VIV31','VIV32','VIV33', 'VIV34', 'VIV35', 'VIV36']]], ignore_index=True)
cob_precio = pd.merge(cob_precio.reset_index(),frame3,how='left', left_on='Clave', right_on='CVEGEO').drop('CVEGEO',axis=1)
cob_precio = cob_precio.set_index('Clave')
dbf = DBF('conjunto_de_datos/SCINCE/cpv2010_loc_rur_migracion.dbf', encoding='unicode_escape')
frame = pd.DataFrame(iter(dbf))
dbf = DBF('conjunto_de_datos/SCINCE/cpv2010_loc_urb_migracion.dbf', encoding='unicode_escape')
frame2 = pd.DataFrame(iter(dbf))
frame3 = pd.concat([frame[['CVEGEO', 'MIG1_R']], frame2[['CVEGEO', 'MIG1_R']]], ignore_index=True)
cob_precio = pd.merge(cob_precio.reset_index(),frame3,how='left', left_on='Clave', right_on='CVEGEO').drop('CVEGEO',axis=1)
cob_precio = cob_precio.set_index('Clave')
dbf = DBF('conjunto_de_datos/SCINCE/cpv2010_loc_rur_caracteristicas_educativas.dbf', encoding='unicode_escape')
frame = pd.DataFrame(iter(dbf))
dbf = DBF('conjunto_de_datos/SCINCE/cpv2010_loc_urb_caracteristicas_educativas.dbf', encoding='unicode_escape')
frame2 = pd.DataFrame(iter(dbf))
frame3 = pd.concat([frame[['CVEGEO', 'EDU37_R', 'EDU49_R']], frame2[['CVEGEO', 'EDU37_R', 'EDU49_R']]], ignore_index=True)
cob_precio = pd.merge(cob_precio.reset_index(),frame3,how='left', left_on='Clave', right_on='CVEGEO').drop('CVEGEO',axis=1)
cob_precio = cob_precio.set_index('Clave')
df = pd.read_csv('conjunto_de_datos/SCINCE/basecompleta.csv', encoding='unicode_escape')
df['Clave']=df.apply(lambda x: zeros(x['ENT'],'ENT') + zeros(x['MUN'],'MUN') + zeros(x['LOC'], 'LOC'),axis=1)
cob_precio = pd.merge(cob_precio.reset_index(),df[['Clave','IM_2010']],how='left',on='Clave')
cob_precio = cob_precio.set_index('Clave')
cob_precio=cob_precio.replace(-6,np.nan)
cob_precio=cob_precio.replace(-9,np.nan)
cob_precio['Empleo'] = cob_precio['ECO4']/cob_precio['ECO1']
cob_precio['Salud'] = cob_precio['SALUD1']/cob_precio['Población']
cob_precio['Lavadora'] = cob_precio['VIV27']/cob_precio['VIV2']
cob_precio['Auto'] = cob_precio['VIV28']/cob_precio['VIV2']
cob_precio['Radio'] = cob_precio['VIV31']/cob_precio['VIV2']
cob_precio['Tele'] = cob_precio['VIV32']/cob_precio['VIV2']
cob_precio['Compu'] = cob_precio['VIV33']/cob_precio['VIV2']
cob_precio['Telefono'] = cob_precio['VIV34']/cob_precio['VIV2']
cob_precio['Celular'] = cob_precio['VIV35']/cob_precio['VIV2']
cob_precio['Internet'] = cob_precio['VIV36']/cob_precio['VIV2']
nB = np.array(list(zip(cob_precio.geometry.x, cob_precio.geometry.y)) )
for col in cob_precio.columns:
    if col != 'geometry':
        cob_precio[col] = cob_precio.apply(lambda x: nanfill(x, col, nB),axis=1)
cob_precio = cob_precio[['Población', '% COB OPER', 'Precio/Tam', 'geometry', 'Empleo',
                   'Salud', 'VIV2', 'MIG1_R','EDU37_R', 'EDU49_R', 'IM_2010', 'Lavadora', 'Auto',
                   'Radio', 'Tele', 'Compu', 'Telefono', 'Celular', 'Internet']]
#cob_precio

# %% [markdown]
# # Análisis exploratorio general

# %%
cob_precio.head()
# Out:
#            Población  % COB OPER   Precio/Tam                     geometry  \
# Clave
# 010010001     722250           1  6099.877565  POINT (-102.29611 21.88083)
# 010010106       1382           1   821.551724  POINT (-102.27444 21.80083)
# 010010120        935           1   527.472577  POINT (-102.29556 21.71750)
# 010010126        509           1   180.000000  POINT (-102.19806 22.00778)
# 010010135        234           1  6341.248721  POINT (-102.31083 21.69944)
#
#              Empleo     Salud    VIV2  MIG1_R  EDU37_R  EDU49_R   IM_2010  \
# Clave
# 010010001  0.937929  0.772303  184123    74.5     23.6     10.0 -1.468581
# 010010106  0.918812  0.802460     255    79.5     36.4      7.0 -1.102892
# 010010120  0.955182  0.760428     217    87.2     39.2      6.5 -1.041144
# 010010126  0.920213  0.760314     123    88.2     32.3      8.7 -1.214816
# 010010135  0.908046  0.841880      47    90.2     39.9      6.9 -0.833872
#
#            Lavadora      Auto     Radio      Tele     Compu  Telefono  \
# Clave
# 010010001  0.855988  0.620688  0.911782  0.983375  0.424211  0.566453
# 010010106  0.815686  0.529412  0.858824  0.980392  0.145098  0.333333
# 010010120  0.783410  0.493088  0.820276  0.976959  0.064516  0.276498
# 010010126  0.747967  0.487805  0.894309  0.943089  0.308943  0.349593
# 010010135  0.723404  0.574468  0.787234  0.914894  0.085106  0.000000
#
#             Celular  Internet
# Clave
# 010010001  0.796663  0.298730
# 010010106  0.745098  0.090196
# 010010120  0.599078  0.055839
# 010010126  0.471545  0.130081
# 010010135  0.723404  0.055839

# %%
cob_precio.describe()
# Out:
#           Población   % COB OPER    Precio/Tam       Empleo        Salud  \
# count  4.654000e+03  4654.000000   4654.000000  4650.000000  4650.000000
# mean   1.400895e+04     0.980447   2351.463320     0.957378     0.630086
# std    8.924953e+04     0.138473   2609.072223     0.043050     0.165371
# min    1.000000e+00     0.000000    149.811015     0.500000     0.000000
# 25%    8.000000e+00     1.000000    666.666667     0.944156     0.540142
# 50%    1.330000e+02     1.000000   1479.560269     0.964892     0.650835
# 75%    1.678000e+03     1.000000   3169.346421     0.985122     0.740741
# max    1.815786e+06     1.000000  21850.000000     1.000000     2.006423
#
#                 VIV2       MIG1_R      EDU37_R      EDU49_R      IM_2010  \
# count    4654.000000  4650.000000  4650.000000  4650.000000  4650.000000
# mean     3605.918350    78.240986    23.582240     7.974222    -0.852086
# std     23012.745954    20.538529     8.571595     2.153540     0.575881
# min         0.000000    -8.000000    -8.000000    -8.000000    -1.818301
# 25%         2.000000    68.100000    19.100000     6.600000    -1.232724
# 50%        33.000000    85.200000    23.700000     7.700000    -0.966822
# 75%       399.250000    93.700000    28.600000     9.000000    -0.616494
# max    453752.000000   100.000000    75.000000    16.500000     3.092976
#
#           Lavadora         Auto        Radio         Tele        Compu  \
# count  4650.000000  4650.000000  4650.000000  4650.000000  4649.000000
# mean      0.628084     0.474767     0.787624     0.920545     0.225789
# std       0.205818     0.219260     0.131177     0.111670     0.205403
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.515084     0.323146     0.730673     0.906547     0.083333
# 50%       0.660965     0.456166     0.807361     0.953158     0.179775
# 75%       0.770323     0.609743     0.869606     0.976870     0.299591
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#           Telefono      Celular     Internet
# count  4643.000000  4650.000000  4649.000000
# mean      0.287383     0.678718     0.149924
# std       0.228240     0.199511     0.190813
# min       0.000000     0.000000     0.000000
# 25%       0.095690     0.571429     0.016771
# 50%       0.262343     0.706652     0.089900
# 75%       0.431628     0.812500     0.197080
# max       1.000000     1.000000     1.000000

# %%
cob_scaled = pd.DataFrame(scale(cob_precio.drop('geometry', axis=1)),columns=cob_precio.drop('geometry', axis=1).columns, index=cob_precio.drop('geometry', axis=1).index)
corrMatrix = cob_scaled.corr()

# %%
corrMatrix
# Out:
#             Población  % COB OPER  Precio/Tam    Empleo     Salud      VIV2  \
# Población    1.000000    0.018527    0.186231 -0.014342  0.028374  0.998373
# % COB OPER   0.018527    1.000000    0.018189 -0.055519  0.024992  0.018783
# Precio/Tam   0.186231    0.018189    1.000000  0.013369 -0.046028  0.189727
# Empleo      -0.014342   -0.055519    0.013369  1.000000 -0.000982 -0.014071
# Salud        0.028374    0.024992   -0.046028 -0.000982  1.000000  0.031242
# VIV2         0.998373    0.018783    0.189727 -0.014071  0.031242  1.000000
# MIG1_R      -0.035813   -0.005043   -0.187738 -0.073692  0.051836 -0.037447
# EDU37_R     -0.019516    0.046404   -0.084854 -0.108706  0.059562 -0.021913
# EDU49_R      0.129335    0.096269    0.215587  0.116456  0.130556  0.132370
# IM_2010     -0.135619   -0.113197   -0.104002 -0.064028 -0.246914 -0.137222
# Lavadora     0.102247    0.076039    0.112495  0.090805  0.248779  0.103879
# Auto         0.021821    0.017612    0.140886  0.073258  0.108291  0.023457
# Radio        0.078190    0.186328    0.106662 -0.030735  0.031655  0.078038
# Tele         0.069981    0.248097    0.057159 -0.026480  0.175436  0.070074
# Compu        0.129896    0.062559    0.265139  0.112028  0.071244  0.133142
# Telefono     0.185007    0.090860    0.229346  0.036389  0.022041  0.186855
# Celular      0.066928    0.175802    0.185381  0.094229  0.091242  0.069318
# Internet     0.124590    0.045931    0.273977  0.112090  0.064439  0.128125
#
#               MIG1_R   EDU37_R   EDU49_R   IM_2010  Lavadora      Auto  \
# Población  -0.035813 -0.019516  0.129335 -0.135619  0.102247  0.021821
# % COB OPER -0.005043  0.046404  0.096269 -0.113197  0.076039  0.017612
# Precio/Tam -0.187738 -0.084854  0.215587 -0.104002  0.112495  0.140886
# Empleo     -0.073692 -0.108706  0.116456 -0.064028  0.090805  0.073258
# Salud       0.051836  0.059562  0.130556 -0.246914  0.248779  0.108291
# VIV2       -0.037447 -0.021913  0.132370 -0.137222  0.103879  0.023457
# MIG1_R      1.000000  0.088619 -0.437894  0.270218 -0.224980 -0.340614
# EDU37_R     0.088619  1.000000 -0.152513 -0.054740 -0.072235 -0.161942
# EDU49_R    -0.437894 -0.152513  1.000000 -0.720981  0.516183  0.564595
# IM_2010     0.270218 -0.054740 -0.720981  1.000000 -0.706254 -0.512619
# Lavadora   -0.224980 -0.072235  0.516183 -0.706254  1.000000  0.577751
# Auto       -0.340614 -0.161942  0.564595 -0.512619  0.577751  1.000000
# Radio      -0.066401 -0.011176  0.368370 -0.405460  0.368470  0.367503
# Tele       -0.030368  0.091443  0.340029 -0.594774  0.512409  0.292552
# Compu      -0.441435 -0.298479  0.826378 -0.585988  0.522810  0.603612
# Telefono   -0.268196 -0.239296  0.653346 -0.565306  0.468708  0.460529
# Celular    -0.409440 -0.039970  0.541550 -0.479497  0.531953  0.528413
# Internet   -0.439396 -0.323981  0.769064 -0.508538  0.462161  0.555770
#
#                Radio      Tele     Compu  Telefono   Celular  Internet
# Población   0.078190  0.069981  0.129896  0.185007  0.066928  0.124590
# % COB OPER  0.186328  0.248097  0.062559  0.090860  0.175802  0.045931
# Precio/Tam  0.106662  0.057159  0.265139  0.229346  0.185381  0.273977
# Empleo     -0.030735 -0.026480  0.112028  0.036389  0.094229  0.112090
# Salud       0.031655  0.175436  0.071244  0.022041  0.091242  0.064439
# VIV2        0.078038  0.070074  0.133142  0.186855  0.069318  0.128125
# MIG1_R     -0.066401 -0.030368 -0.441435 -0.268196 -0.409440 -0.439396
# EDU37_R    -0.011176  0.091443 -0.298479 -0.239296 -0.039970 -0.323981
# EDU49_R     0.368370  0.340029  0.826378  0.653346  0.541550  0.769064
# IM_2010    -0.405460 -0.594774 -0.585988 -0.565306 -0.479497 -0.508538
# Lavadora    0.368470  0.512409  0.522810  0.468708  0.531953  0.462161
# Auto        0.367503  0.292552  0.603612  0.460529  0.528413  0.555770
# Radio       1.000000  0.465058  0.334895  0.366100  0.328690  0.276471
# Tele        0.465058  1.000000  0.263850  0.311992  0.367633  0.214223
# Compu       0.334895  0.263850  1.000000  0.723991  0.505881  0.895159
# Telefono    0.366100  0.311992  0.723991  1.000000  0.257951  0.736061
# Celular     0.328690  0.367633  0.505881  0.257951  1.000000  0.440085
# Internet    0.276471  0.214223  0.895159  0.736061  0.440085  1.000000

# %%
fig, ax = plt.subplots(figsize=(15,15))
sn.heatmap(corrMatrix, annot=True)

# %%
cob_precio.groupby('% COB OPER').count()
# Out:
#             Población  Precio/Tam  geometry  Empleo  Salud  VIV2  MIG1_R  \
# % COB OPER
# 0                  91          91        91      91     91    91      91
# 1                4563        4563      4563    4559   4559  4563    4559
#
#             EDU37_R  EDU49_R  IM_2010  Lavadora  Auto  Radio  Tele  Compu  \
# % COB OPER
# 0                91       91       91        91    91     91    91     91
# 1              4559     4559     4559      4559  4559   4559  4559   4558
#
#             Telefono  Celular  Internet
# % COB OPER
# 0                 91       91        91
# 1               4552     4559      4558

# %%
precio_por_cober = cob_precio.groupby('% COB OPER').mean()
precio_por_cober
# Out:
#                Población   Precio/Tam    Empleo     Salud         VIV2  \
# % COB OPER
# 0            2301.142857  2015.450266  0.974294  0.600837   545.373626
# 1           14242.442910  2358.164435  0.957041  0.630670  3666.954854
#
#                MIG1_R    EDU37_R  EDU49_R   IM_2010  Lavadora      Auto  \
# % COB OPER
# 0           78.973993  20.767216  6.50696 -0.390732  0.517322  0.447438
# 1           78.226354  23.638429  8.00351 -0.861295  0.630294  0.475313
#
#                Radio      Tele     Compu  Telefono   Celular  Internet
# % COB OPER
# 0           0.614642  0.724469  0.134857  0.140728  0.430485  0.087903
# 1           0.791077  0.924459  0.227605  0.290315  0.683673  0.151162

# %%
plt.bar(precio_por_cober.index,precio_por_cober['Precio/Tam'] )
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# # Análisis de clusters

# %%
km5 = cluster.KMeans(n_clusters=5)

# %%
km5cls = km5.fit(cob_scaled.values)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-55be24c7610a> in <module>()
# ----> 1 km5cls = km5.fit(cob_scaled.values)
#
# c:\programdata\miniconda3\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#     857         order = "C" if self.copy_x else None
#     858         X = check_array(X, accept_sparse='csr', dtype=[np.float64, np.float32],
# --> 859                         order=order, copy=self.copy_x)
#     860         # verify that the number of samples given is larger than k
#     861         if _num_samples(X) < self.n_clusters:
#
# c:\programdata\miniconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     576         if force_all_finite:
#     577             _assert_all_finite(array,
# --> 578                                allow_nan=force_all_finite == 'allow-nan')
#     579
#     580     if ensure_min_samples > 0:
#
# c:\programdata\miniconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      58                     msg_err.format
#      59                     (type_err,
# ---> 60                      msg_dtype if msg_dtype is not None else X.dtype)
#      61             )
#      62     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
clusters = cob_precio.assign(cl=km5cls.labels_)
clusters

# %%
fig, ax = plt.subplots(figsize=(15,15))
mex.plot(ax=ax,color='white',edgecolor='black')
clusters.plot(column='cl', categorical=True, legend=True, 
         linewidth=0.1, edgecolor='white', ax=ax)

plt.show()

# %%
clusters.groupby('cl').mean()

# %%
clusters.groupby('cl').count()

# %% [markdown]
# # Regresión lineal

# %% [markdown]
# ## Precio/m$^2$ como variable dependiente

# %%
cob_precio.groupby('% COB OPER').count()

# %%
cob_precio.drop('geometry').describe()

# %%
X = cob_scaled.drop('Precio/Tam').values
y = cob_precio['Precio/Tam'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=cob_scaled['% COB OPER'].values)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train)

# %%
coeff_df = pd.DataFrame(regressor.coef_, cob_scaled.drop('Precio/Tam').columns, columns=['Coefficient'])  
coeff_df

# %%
regressor.intercept_

# %%
y_pred = regressor.predict(X_test)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# %%
regressor.score(cob_scaled.drop('Precio/Tam'), cob_precio['Precio/Tam'])

# %% [markdown]
# ## % COB OPER como variable dependiente

# %%
X = cob_scaled.drop('% COB OPER').values
y = cob_precio['% COB OPER'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train)

# %%
coeff_df = pd.DataFrame(regressor.coef_, cob_scaled.drop('% COB OPER').columns, columns=['Coefficient'])  
coeff_df

# %%
y_pred = regressor.predict(X_test)

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df1 = df.head(25)

# %%
df[df['Actual']==0]

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# %%
y.mean()

# %% [markdown]
# # Zonas de interés

# %% [markdown]
# ## Nuevo León

# %% [markdown]
# ### Precios

# %%
fig, ax = plt.subplots(figsize=(15,15))
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
mex[mex['NOMGEO'] == 'Nuevo León'].plot(ax=ax)
cob_precio.loc['19':'20'].plot(ax=ax,markersize=10,column='Precio/Tam', legend=True,cax=cax, cmap='plasma')
cob_precio.loc['19':'20'][(cob_precio['% COB OPER']==0)].plot(ax=ax, markersize=20, color='#58F011',marker='*',legend=True)
red_patch = mpatches.Patch(color='#58F011', label='Localidades sin cobertura')
plt.legend(handles=[red_patch],bbox_to_anchor=(.70,.85),bbox_transform=plt.gcf().transFigure)
#plt.scatter(cob_precio.geometry.x,cob_precio.geometry.y,c=cob_precio['COB OPERAD']=='SI', cmap = cm.RdYlGn)
plt.show()

# %% [markdown]
# ### Análisis exploratorio

# %%
nleon = gpd.GeoDataFrame(pd.merge(cob_scaled.loc['19':'20'],cob_precio['geometry'],how='left', on='Clave'))
corrMatrix = cob_precio.loc['19':'20'][['Población','% COB OPER','Precio/Tam']].corr()
#cob_

# %%
corrMatrix

# %%
sn.heatmap(corrMatrix, annot=True)

# %%
cob_precio.loc['19':'20'].groupby('% COB OPER').count()

# %%
precio_por_cober = cob_precio.loc['19':'20'].groupby('% COB OPER').mean()
precio_por_cober

# %%
plt.bar(precio_por_cober.index,precio_por_cober['Precio/Tam'] )

# %%
plt.scatter(nleon['Precio/Tam'], nleon['Población'])

# %% [markdown]
# ### Clusters aglomerativos

# %%
wtq = lp.weights.Queen.from_dataframe(nleon)
wtq.n

# %%
model = cluster.AgglomerativeClustering(linkage='ward',
                                            connectivity=wtq.sparse,
                                            n_clusters=5)
model.fit(nleon[['Precio/Tam','% COB OPER','Población']])

# %%
nleon['cl'] = model.labels_

# %%
fig, ax = plt.subplots(figsize=(15,15))
mex[(mex['NOMGEO'] == 'Nuevo León')].plot(ax=ax,color='white',edgecolor='black')
#xmin,ymin,xmax,ymax = mex1[(mex1['NOMGEO'] == 'México')].total_bounds
#mex.plot(ax=ax,color='white',edgecolor='black')
nleon.plot(column='cl', categorical=True, legend=True, 
         linewidth=0.1, edgecolor='white', ax=ax)

plt.show()

# %% [markdown]
# ### Clusters

# %%
fig, ax = plt.subplots(figsize=(15,15))
mex[(mex['NOMGEO'] == 'Nuevo León')].plot(ax=ax,color='white',edgecolor='black')
#xmin,ymin,xmax,ymax = mex1[(mex1['NOMGEO'] == 'México')].total_bounds
#mex.plot(ax=ax,color='white',edgecolor='black')
clusters.loc['19':'20'].plot(column='cl', categorical=True, legend=True, 
         linewidth=0.1, edgecolor='white', ax=ax)

plt.show()

# %% [markdown]
# ## Quintana Roo

# %% [markdown]
# ### Precios

# %%
fig, ax = plt.subplots(figsize=(15,15))
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
mex[mex['NOMGEO'] == 'Quintana Roo'].plot(ax=ax)
cob_precio.loc['23':'24'].plot(ax=ax,markersize=10,column='Precio/Tam', legend=True,cax=cax, cmap='plasma')
cob_precio.loc['23':'24'][(cob_precio['% COB OPER']==0)].plot(ax=ax, markersize=20, color='#58F011',marker='*',legend=True)
red_patch = mpatches.Patch(color='#58F011', label='Localidades sin cobertura')
plt.legend(handles=[red_patch],bbox_to_anchor=(.70,.85),bbox_transform=plt.gcf().transFigure)
#plt.scatter(cob_precio.geometry.x,cob_precio.geometry.y,c=cob_precio['COB OPERAD']=='SI', cmap = cm.RdYlGn)
plt.show()

# %% [markdown]
# ### Análisis exploratorio

# %%
qroo = gpd.GeoDataFrame(pd.merge(cob_scaled.loc['23':'24'],cob_precio['geometry'],how='left', on='Clave'))
corrMatrix = cob_precio.loc['23':'24'][['Población','% COB OPER','Precio/Tam']].corr()
#cob_

# %%
corrMatrix

# %%
sn.heatmap(corrMatrix, annot=True)

# %%
cob_precio.loc['23':'24'].groupby('% COB OPER').count()

# %%
precio_por_cober = cob_precio.loc['23':'24'].groupby('% COB OPER').mean()
precio_por_cober

# %%
plt.bar(precio_por_cober.index,precio_por_cober['Precio/Tam'] )

# %%
plt.scatter(qroo['Precio/Tam'], qroo['Población'])

# %% [markdown]
# ### Clusters aglomerativos

# %%
wtq = lp.weights.Queen.from_dataframe(qroo)
wtq.n

# %%
model = cluster.AgglomerativeClustering(linkage='ward',
                                            connectivity=wtq.sparse,
                                            n_clusters=5)
model.fit(qroo[['Precio/Tam','% COB OPER','Población']])

# %%
qroo['cl'] = model.labels_

# %%
fig, ax = plt.subplots(figsize=(15,15))
mex[(mex['NOMGEO'] == 'Quintana Roo')].plot(ax=ax,color='white',edgecolor='black')
#xmin,ymin,xmax,ymax = mex1[(mex1['NOMGEO'] == 'México')].total_bounds
#mex.plot(ax=ax,color='white',edgecolor='black')
qroo.plot(column='cl', categorical=True, legend=True, 
         linewidth=0.1, edgecolor='white', ax=ax)

plt.show()

# %% [markdown]
# ### Clusters

# %%
fig, ax = plt.subplots(figsize=(15,15))
mex[(mex['NOMGEO'] == 'Quintana Roo')].plot(ax=ax,color='white',edgecolor='black')
#xmin,ymin,xmax,ymax = mex1[(mex1['NOMGEO'] == 'México')].total_bounds
#mex.plot(ax=ax,color='white',edgecolor='black')
clusters.loc['23':'24'].plot(column='cl', categorical=True, legend=True, 
         linewidth=0.1, edgecolor='white', ax=ax)

plt.show()

# %% [markdown]
# ## Baja California Sur

# %% [markdown]
# ### Precios

# %%
fig, ax = plt.subplots(figsize=(15,15))
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
mex[mex['NOMGEO'] == 'Baja California Sur'].plot(ax=ax)
cob_precio.loc['03':'04'].plot(ax=ax,markersize=10,column='Precio/Tam', legend=True,cax=cax, cmap='plasma')
cob_precio.loc['03':'04'][(cob_precio['% COB OPER']==0)].plot(ax=ax, markersize=20, color='#58F011',marker='*',legend=True)
red_patch = mpatches.Patch(color='#58F011', label='Localidades sin cobertura')
plt.legend(handles=[red_patch],bbox_to_anchor=(.70,.85),bbox_transform=plt.gcf().transFigure)
#plt.scatter(cob_precio.geometry.x,cob_precio.geometry.y,c=cob_precio['COB OPERAD']=='SI', cmap = cm.RdYlGn)
plt.show()

# %% [markdown]
# ### Análisis exploratorio

# %%
bcs = gpd.GeoDataFrame(pd.merge(cob_scaled.loc['03':'04'],cob_precio['geometry'],how='left', on='Clave'))
corrMatrix = cob_precio.loc['03':'04'][['Población','% COB OPER','Precio/Tam']].corr()
#cob_

# %%
corrMatrix

# %%
sn.heatmap(corrMatrix, annot=True)

# %%
cob_precio.loc['03':'04'].groupby('% COB OPER').count()

# %%
precio_por_cober = cob_precio.loc['03':'04'].groupby('% COB OPER').mean()
precio_por_cober

# %%
plt.bar(precio_por_cober.index,precio_por_cober['Precio/Tam'] )

# %%
plt.scatter(bcs['Precio/Tam'], bcs['Población'])

# %% [markdown]
# ### Clusters aglomerativos

# %%
bcs = gpd.GeoDataFrame(pd.merge(cob_scaled.loc['03':'04'],cob_precio['geometry'],how='left', on='Clave'))
wtq = lp.weights.Queen.from_dataframe(bcs)
wtq.n

# %%
model = cluster.AgglomerativeClustering(linkage='ward',
                                            connectivity=wtq.sparse,
                                            n_clusters=5)
model.fit(bcs[['Precio/Tam','% COB OPER','Población']])

# %%
bcs['cl'] = model.labels_

# %%
fig, ax = plt.subplots(figsize=(15,15))
mex[(mex['NOMGEO'] == 'Baja California Sur')].plot(ax=ax,color='white',edgecolor='black')
#xmin,ymin,xmax,ymax = mex1[(mex1['NOMGEO'] == 'México')].total_bounds
#mex.plot(ax=ax,color='white',edgecolor='black')
bcs.plot(column='cl', categorical=True, legend=True, 
         linewidth=0.1, edgecolor='white', ax=ax)

plt.show()

# %% [markdown]
# ### Clusters

# %%
fig, ax = plt.subplots(figsize=(15,15))
mex[(mex['NOMGEO'] == 'Baja California Sur')].plot(ax=ax,color='white',edgecolor='black')
#xmin,ymin,xmax,ymax = mex1[(mex1['NOMGEO'] == 'México')].total_bounds
#mex.plot(ax=ax,color='white',edgecolor='black')
clusters.loc['03':'04'].plot(column='cl', categorical=True, legend=True, 
         linewidth=0.1, edgecolor='white', ax=ax)

plt.show()

# %%
model = LinearRegression().fit(cob_precio[['Población', '% COB OPER']], cob_precio['Precio/Tam'])

# %%
model.coef_

# %%
model.intercept_

# %%
model.score(cob_precio[['Población', '% COB OPER']], cob_precio['Precio/Tam'])

# %%
cob_precio[['Población', '% COB OPER','Precio/Tam']].describe()

# %%
X = cob_precio[['Población', 'Precio/Tam']].values
y = cob_precio['% COB OPER'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train)

# %%
coeff_df = pd.DataFrame(regressor.coef_, ['Población', 'Precio/Tam'], columns=['Coefficient'])  
coeff_df

# %%
y_pred = regressor.predict(X_test)

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df1 = df.head(25)

# %%
df[df['Actual']==0]

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# %%
y.mean()

# %% [markdown]
# # Pruebas

# %%
dbf = DBF('conjunto_de_datos/SCINCE/cpv2010_loc_rur_caracteristicas_economicas.dbf', encoding='unicode_escape')
frame = pd.DataFrame(iter(dbf))
dbf = DBF('conjunto_de_datos/SCINCE/cpv2010_loc_urb_caracteristicas_economicas.dbf', encoding='unicode_escape')
frame2 = pd.DataFrame(iter(dbf))
frame3 = pd.concat([frame[['CVEGEO', 'ECO1', 'ECO4']], frame2[['CVEGEO', 'ECO1', 'ECO4']]], ignore_index=True)
prueba1 = pd.merge(cob_precio.reset_index(),frame3,how='left', left_on='Clave', right_on='CVEGEO').drop('CVEGEO',axis=1)
prueba1 = prueba1.set_index('Clave')
#prueba1 = prueba1.replace(-6,np.nan)
dbf = DBF('conjunto_de_datos/SCINCE/cpv2010_loc_rur_servicios_de_salud.dbf', encoding='unicode_escape')
frame = pd.DataFrame(iter(dbf))
dbf = DBF('conjunto_de_datos/SCINCE/cpv2010_loc_urb_servicios_de_salud.dbf', encoding='unicode_escape')
frame2 = pd.DataFrame(iter(dbf))
frame3 = pd.concat([frame[['CVEGEO', 'SALUD1']], frame2[['CVEGEO', 'SALUD1']]], ignore_index=True)
prueba1 = pd.merge(prueba1.reset_index(),frame3,how='left', left_on='Clave', right_on='CVEGEO').drop('CVEGEO',axis=1)
prueba1 = prueba1.set_index('Clave')
#prueba1 = prueba1.replace(-6,np.nan)
dbf = DBF('conjunto_de_datos/SCINCE/cpv2010_loc_rur_viviendas.dbf', encoding='unicode_escape')
frame = pd.DataFrame(iter(dbf))
dbf = DBF('conjunto_de_datos/SCINCE/cpv2010_loc_urb_viviendas.dbf', encoding='unicode_escape')
frame2 = pd.DataFrame(iter(dbf))
frame3 = pd.concat([frame[['CVEGEO', 'VIV2', 'VIV27', 'VIV28', 'VIV31',
                          'VIV32','VIV33', 'VIV34', 'VIV35', 'VIV36']], 
                    frame2[['CVEGEO','VIV2', 'VIV27', 'VIV28',
                          'VIV31','VIV32','VIV33', 'VIV34', 'VIV35', 'VIV36']]], ignore_index=True)
prueba1 = pd.merge(prueba1.reset_index(),frame3,how='left', left_on='Clave', right_on='CVEGEO').drop('CVEGEO',axis=1)
prueba1 = prueba1.set_index('Clave')
#prueba1 = prueba1.replace(-6,np.nan)
dbf = DBF('conjunto_de_datos/SCINCE/cpv2010_loc_rur_migracion.dbf', encoding='unicode_escape')
frame = pd.DataFrame(iter(dbf))
dbf = DBF('conjunto_de_datos/SCINCE/cpv2010_loc_urb_migracion.dbf', encoding='unicode_escape')
frame2 = pd.DataFrame(iter(dbf))
frame3 = pd.concat([frame[['CVEGEO', 'MIG1_R']], frame2[['CVEGEO', 'MIG1_R']]], ignore_index=True)
prueba1 = pd.merge(prueba1.reset_index(),frame3,how='left', left_on='Clave', right_on='CVEGEO').drop('CVEGEO',axis=1)
prueba1 = prueba1.set_index('Clave')
#prueba1 = prueba1.replace(-6,np.nan)
dbf = DBF('conjunto_de_datos/SCINCE/cpv2010_loc_rur_caracteristicas_educativas.dbf', encoding='unicode_escape')
frame = pd.DataFrame(iter(dbf))
dbf = DBF('conjunto_de_datos/SCINCE/cpv2010_loc_urb_caracteristicas_educativas.dbf', encoding='unicode_escape')
frame2 = pd.DataFrame(iter(dbf))
frame3 = pd.concat([frame[['CVEGEO', 'EDU37_R', 'EDU49_R']], frame2[['CVEGEO', 'EDU37_R', 'EDU49_R']]], ignore_index=True)
prueba1 = pd.merge(prueba1.reset_index(),frame3,how='left', left_on='Clave', right_on='CVEGEO').drop('CVEGEO',axis=1)
prueba1 = prueba1.set_index('Clave')
#prueba1 = prueba1.replace(-6,np.nan)
df = pd.read_csv('conjunto_de_datos/SCINCE/basecompleta.csv', encoding='unicode_escape')
df['Clave']=df.apply(lambda x: zeros(x['ENT'],'ENT') + zeros(x['MUN'],'MUN') + zeros(x['LOC'], 'LOC'),axis=1)
prueba1 = pd.merge(prueba1.reset_index(),df[['Clave','IM_2010']],how='left',on='Clave')
prueba1 = prueba1.set_index('Clave')
prueba1=prueba1.replace(-6,np.nan)
prueba1=prueba1.replace(-9,np.nan)
prueba1['Empleo'] = prueba1['ECO4']/prueba1['ECO1']
prueba1['Salud'] = prueba1['SALUD1']/prueba1['Población']
prueba1['Lavadora'] = prueba1['VIV27']/prueba1['VIV2']
prueba1['Auto'] = prueba1['VIV28']/prueba1['VIV2']
prueba1['Radio'] = prueba1['VIV31']/prueba1['VIV2']
prueba1['Tele'] = prueba1['VIV32']/prueba1['VIV2']
prueba1['Compu'] = prueba1['VIV33']/prueba1['VIV2']
prueba1['Telefono'] = prueba1['VIV34']/prueba1['VIV2']
prueba1['Celular'] = prueba1['VIV35']/prueba1['VIV2']
prueba1['Internet'] = prueba1['VIV36']/prueba1['VIV2']
nB = np.array(list(zip(prueba1.geometry.x, prueba1.geometry.y)) )
for col in prueba1.columns:
    if col != 'geometry':
        prueba1[col] = prueba1.apply(lambda x: nanfill(x, col, nB),axis=1)
prueba1 = prueba1[['Población', '% COB OPER', 'Precio/Tam', 'geometry', 'Empleo',
                   'Salud', 'VIV2', 'MIG1_R','EDU37_R', 'EDU49_R', 'IM_2010', 'Lavadora', 'Auto',
                   'Radio', 'Tele', 'Compu', 'Telefono', 'Celular', 'Internet']]
prueba1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\programdata\miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'VIV2'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-7b731e0cc336> in <module>()
#      50 prueba1['Empleo'] = prueba1['ECO4']/prueba1['ECO1']
#      51 prueba1['Salud'] = prueba1['SALUD1']/prueba1['Población']
# ---> 52 prueba1['Lavadora'] = prueba1['VIV27']/prueba1['VIV2']
#      53 prueba1['Auto'] = prueba1['VIV28']/prueba1['VIV2']
#      54 prueba1['Radio'] = prueba1['VIV31']/prueba1['VIV2']
#
# c:\programdata\miniconda3\lib\site-packages\geopandas\geodataframe.py in __getitem__(self, key)
#     544         GeoDataFrame.
#     545         """
# --> 546         result = super(GeoDataFrame, self).__getitem__(key)
#     547         geo_col = self._geometry_column_name
#     548         if isinstance(key, string_types) and key == geo_col:
#
# c:\programdata\miniconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# c:\programdata\miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'VIV2'

# %%
def nanfill(row,col,nB):
    if math.isnan(row[col]):
        nA = np.array([row['geometry'].x, prueba1.loc['320560187']['geometry'].y])
        btree = cKDTree(nB)
        dist, idx = btree.query(nA, k=11)
        nearest = prueba1.iloc[idx[1:]]
        disp = nearest[nearest[col].notnull()]
        prom = disp[col].head(3).mean()
        return prom
    else:
        return row[col]

# %%
cob_scaled1 = pd.DataFrame(scale(prueba1.drop('geometry', axis=1)),columns=prueba1.drop('geometry', axis=1).columns, index=prueba1.drop('geometry', axis=1).index)

# %%
km5 = cluster.KMeans(n_clusters=5)

# %%
km5cls = km5.fit(cob_scaled1.values)

# %%
clusters = prueba1.assign(cl=km5cls.labels_)
clusters

# %%
fig, ax = plt.subplots(figsize=(15,15))
mex.plot(ax=ax,color='white',edgecolor='black')
clusters.plot(column='cl', categorical=True, legend=True, 
         linewidth=0.1, edgecolor='white', ax=ax)

plt.show()

# %%
clusters.groupby('cl').mean()

# %%
clusters.groupby('cl').count()

# %%
def zeros(val,tipo):
    add = ''
    if tipo=='ENT':
        if val//10==0:
            add='0'
    if tipo == 'MUN':
        if val//100==0:
            if val//10==0:
                add='00'
            else:
                add='0'
    if tipo == 'LOC':
        if val//1000==0:
            if val//100==0:
                if val//10==0:
                    add = '000'
                else:
                    add = '00'
            else:
                add = '0'
    return add + str(val)

# %%
corrMatrix = cob_scaled1.corr()

# %%
corrMatrix

# %%
fig, ax = plt.subplots(figsize=(15,15))
sn.heatmap(corrMatrix, annot=True)

# %%
? sn.heatmap
